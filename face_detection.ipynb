# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dlib

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import os
os.chdir('Y:\\face_dect\\PRJ Face Detection\\Data Set\\')

# %%
image = cv2.imread('people1.jpg')
display (image.shape)
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(image)
plt.show()

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
cv2.imshow('', image)
cv2.waitKey(10000)
# cv2.destroyAllWindows() simply destroys all the windows we created.
cv2.destroyAllWindows()

# %%
image = cv2.resize(image, (1000, 700))
print (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
cv2.destroyAllWindows()
# Out:
# (700, 1000, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()
display (image_gray.shape)
# Out:
# (700, 1000)

# %% [markdown]
# # Model CascadeClassifier

# %%
face_detector = cv2.CascadeClassifier('Y:\\face_dect\\PRJ Face Detection\\Cascades\\haarcascade_frontalface_default.xml')
display (face_detector)
# Out:
# < cv2.CascadeClassifier 0000027B8353BE90>

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
display (len(detections))
# Out:
# array([[148, 145,  59,  59],
#        [599, 145,  66,  66],
#        [851,  87,  77,  77],
#        [538,  72, 201, 201],
#        [489, 273,  80,  80],
#        [122, 280,  73,  73]])
# 6

# %%
x=146  # X - Co ordinates 
y=144  # Y- Co ordinates 
w=62   # Face Width
h=62   # Face Height 
# Draw the rectangle with co-ordinate specified above 
# (0,255,255) - This is RBG colour for rectangle 
# 1 is the thickness of rectangle 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (100,255,25), 3)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\people1.jpg')
display (image.shape)
image = cv2.resize(image, (1000, 700)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image,scaleFactor = 1.21)
display (detections)
# Out:
# (1280, 1920, 3)
# (700, 1000, 3)
# array([[145, 144,  62,  62],
#        [849,  83,  82,  82],
#        [597, 142,  71,  71],
#        [485, 270,  88,  88],
#        [117, 277,  78,  78]])

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %% [markdown]
# minNeighbors

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\people2.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,minNeighbors=7)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[717, 100,  46,  46],
#        [424,  31,  47,  47],
#        [321,  48,  47,  47],
#        [600,  60,  49,  49],
#        [168,  35,  49,  49],
#        [380,  54,  52,  52],
#        [906,  63,  51,  51],
#        [234,  46,  50,  50],
#        [662,  83,  44,  44],
#        [480,  70,  47,  47],
#        [ 91,  81,  51,  51],
#        [825,  91,  51,  51]])
# 46 46
# 47 47
# 47 47
# 49 49
# 49 49
# 52 52
# 51 51
# 50 50
# 44 44
# 47 47
# 51 51
# 51 51

# %% [markdown]
# minSize and  maxSize

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,
                                            minNeighbors=6,minSize=(65,50), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# ()

# %% [markdown]
# # Eye Detector

# %%
eye_detector= cv2.CascadeClassifier('Y:\\face_dect\\PRJ Face Detection\\Cascades\\haarcascade_eye.xml')
display (eye_detector)
# Out:
# < cv2.CascadeClassifier 0000027B8353B390>

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\people1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (1280, 1920, 3)
# (1000, 1600, 3)
# 22 22
# 30 30
# 23 23
# 22 22
# 29 29
# 33 33
# 31 31
# 25 25
# 33 33

# %% [markdown]
# # car Detector

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\car.jpg')
display (image.shape)

car_detector = cv2.CascadeClassifier('Y:\\face_dect\\PRJ Face Detection\\Cascades\\cars.xml')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.02, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (286, 468, 3)

# %% [markdown]
# # Clock Detector

# %%
clock_detector = cv2.CascadeClassifier('Y:\\face_dect\\PRJ Face Detection\\Cascades\\clocks.xml')

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\clock.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = clock_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %% [markdown]
# # Full Body Detector

# %%
full_detector  = cv2.CascadeClassifier('Y:\\face_dect\\PRJ Face Detection\\Cascades\\fullbody.xml')

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\people3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray, scaleFactor = 1.05, minNeighbors=5,    minSize = (50,55)) 
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %% [markdown]
# # Face detection with HOG and Dlib

# %%
image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1) # 1 – is the scale factor 
display (len(detections))
display (detections)
# Out:
# 14
# rectangles[[(429, 38) (465, 74)], [(665, 90) (701, 126)], [(717, 103) (760, 146)], [(909, 70) (952, 113)], [(828, 98) (871, 142)], [(605, 70) (641, 106)], [(777, 62) (813, 98)], [(485, 78) (521, 114)], [(386, 60) (429, 103)], [(170, 41) (213, 84)], [(93, 89) (136, 132)], [(237, 50) (280, 94)], [(323, 50) (367, 94)], [(544, 65) (588, 108)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# [(429, 38) (465, 74)]
# 429
# 38
# 465
# 74

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %% [markdown]
# # Face detection with CNN and Dlib

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('Y:\\face_dect\\PRJ Face Detection\\Weights\\mmod_human_face_detector.dat')
display (cnn_detector)

image = cv2.imread('Y:\\face_dect\\PRJ Face Detection\\Data Set\\people2.jpg')

detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# 1.1440682411193848
# 1.137049913406372
# 1.1278996467590332
# 1.1200228929519653
# 1.1149370670318604
# 1.1131553649902344
# 1.097571611404419
# 1.0942120552062988
# 1.085314154624939
# 1.0801892280578613
# 1.0800764560699463
# 1.0784764289855957
# 1.0664036273956299
# 1.0641793012619019

# %% [markdown]
# # END
